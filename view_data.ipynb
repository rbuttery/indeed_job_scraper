# %%
from database_tools import DatabaseTools
db = DatabaseTools()

# Select all the tables in the database
db.list_tables()
# Out:
# Listing tables in database: d:\GAN Tutorial\indeed_job_scraper\indeed.db
# ['search_sessions', 'job_postings', 'job_details']

# %%
df_job_details = db.sql_to_df("select * from job_details")
df_job_details
# Out:
# Empty DataFrame
# Columns: [id, job_unique_id, position_summary, salary, location, employer, education, key_skills, employment_type, work_environment, experience_level, responsibilities, benefits, application_deadline, industry, timestamp]
# Index: []

# %%
df_search_sessions = db.sql_to_df("select * from search_sessions")
df_search_sessions
# Out:
#    id        terms   location  \
# 0   1  ML Engineer  Bengaluru
# 1   2  ML Engineer  Bengaluru
#
#                                          filter_tags  n_pages ended_at  \
# 0  [{"name": "Date posted", "options": ["Last 24 ...        1     None
# 1  [{"name": "Date posted", "options": ["Last 24 ...        1     None
#
#             started_at
# 0  2024-05-20 16:22:08
# 1  2024-05-20 16:25:57

# %%
df_recent_session_id = df_search_sessions['id'].tail(1).item()
df_recent_session_id
# Out:
# 2

# %%
term = df_search_sessions.loc[df_search_sessions['id'] == df_recent_session_id, 'terms'].item()
loc = df_search_sessions.loc[df_search_sessions['id'] == df_recent_session_id, 'location'].item()
# pages = df_search_sessions.loc[df_search_sessions['id'] == df_recent_session_id, 'n_pages'].item()
print(term, loc, pages)
# Out:
# ML Engineer Bengaluru 1

# %%
# Select the records that were collected today
df = db.sql_to_df("select * from job_postings where date(timestamp) = date('now')")
df = df.loc[df['session_id'] == df_recent_session_id]
df
# Out:
#     id  session_id         job_unique_id  \
# 0    1           1  job_bc282074a8a7a638
# 1    2           1  job_51b279cfb3ef2a1e
# 2    3           1  job_05319c820538a77d
# 3    4           1  job_54331f629964d93e
# 4    5           1  job_2098652ac931a9d7
# 5    6           1  job_5e231435a2484c54
# 6    7           1  job_a91c2df97f8d9446
# 7    8           1  job_7fd5c870ec9a1038
# 8    9           1  job_29208503f6c1436f
# 9   10           1  job_94c42e65209476dd
# 10  11           1  job_42b3940c00cd8a40
# 11  12           1  job_e9a7c6ffd101e106
# 12  13           1  job_78259c40a822f862
# 13  14           1  job_5c302da1dbbe8a66
# 14  15           1  job_5a6b0c878fa75a0c
#
#                                             job_title  \
# 0   Data Domain Architect Analyst - Data Annotatio...
# 1               Software Engineer III - Python, React
# 2   Manager of Software Engineering - Python, Spar...
# 3     Staff Data Engineer - AI/ML Visa AI as Services
# 4                                   Software Engineer
# 5                                   Software Engineer
# 6                                      MLOps Engineer
# 7   Automation Tester with Selenium_9-15 Years_Man...
# 8                                   Sr Lead Architect
# 9                                   Staff AI Engineer
# 10                                Lead MLOps Engineer
# 11  ML Manager - Operations Business Process Reeng...
# 12                      Sr. Manager - Global Analytic
# 13      GE Vernova Advanced Research - Intern - AI/ML
# 14      GE Vernova Advanced Research - Intern - AI/ML
#
#                                              job_link  \
# 0   https://in.indeed.com/rc/clk?jk=bc282074a8a7a6...
# 1   https://in.indeed.com/rc/clk?jk=51b279cfb3ef2a...
# 2   https://in.indeed.com/rc/clk?jk=05319c820538a7...
# 3   https://in.indeed.com/rc/clk?jk=54331f629964d9...
# 4   https://in.indeed.com/rc/clk?jk=2098652ac931a9...
# 5   https://in.indeed.com/rc/clk?jk=5e231435a2484c...
# 6   https://in.indeed.com/rc/clk?jk=a91c2df97f8d94...
# 7   https://in.indeed.com/rc/clk?jk=7fd5c870ec9a10...
# 8   https://in.indeed.com/rc/clk?jk=29208503f6c143...
# 9   https://in.indeed.com/rc/clk?jk=94c42e65209476...
# 10  https://in.indeed.com/rc/clk?jk=42b3940c00cd8a...
# 11  https://in.indeed.com/rc/clk?jk=e9a7c6ffd101e1...
# 12  https://in.indeed.com/rc/clk?jk=78259c40a822f8...
# 13  https://in.indeed.com/rc/clk?jk=5c302da1dbbe8a...
# 14  https://in.indeed.com/rc/clk?jk=5a6b0c878fa75a...
#
#                                       job_description  \
# 0   Data Domain Architect Analyst - Data Annotatio...
# 1   Software Engineer III - Python, React\n=======...
# 2   Manager of Software Engineering - Python, Spar...
# 3   Staff Data Engineer - AI/ML Visa AI as Service...
# 4   ![Applied Materials logo](https://d2q79iu7y748...
# 5   Software Engineer\n=================\n\n[Micro...
# 6   MLOps Engineer\n==============\n\n[Adobe](http...
# 7   ![EY logo](https://d2q79iu7y748jz.cloudfront.n...
# 8   Sr Lead Architect\n=================\n\n[JPMor...
# 9   Staff AI Engineer\n=================\n\nWe Rem...
# 10  Lead MLOps Engineer\n===================\n\n[D...
# 11  ![Apple logo](https://d2q79iu7y748jz.cloudfron...
# 12  ![Concentrix logo](https://d2q79iu7y748jz.clou...
# 13  GE Vernova Advanced Research - Intern - AI/ML\...
# 14  GE Vernova Advanced Research - Intern - AI/ML\...
#
#                          job_company            timestamp
# 0                JPMorgan Chase & Co  2024-05-20 16:22:09
# 1                JPMorgan Chase & Co  2024-05-20 16:22:10
# 2                JPMorgan Chase & Co  2024-05-20 16:22:10
# 3                               Visa  2024-05-20 16:22:11
# 4                  Applied Materials  2024-05-20 16:22:11
# 5                          Microsoft  2024-05-20 16:22:11
# 6                              Adobe  2024-05-20 16:22:12
# 7                                 EY  2024-05-20 16:22:12
# 8                JPMorgan Chase & Co  2024-05-20 16:22:13
# 9                     We Remote Devs  2024-05-20 16:22:13
# 10                    DXC Technology  2024-05-20 16:22:13
# 11                             Apple  2024-05-20 16:22:14
# 12                        Concentrix  2024-05-20 16:22:14
# 13  GE Vernova Strategy & Innovation  2024-05-20 16:22:15
# 14                        GE Vernova  2024-05-20 16:22:15

# %%
df.to_csv(f'job_postings_india_{term}_{loc}_{df_recent_session_id}.csv')

# %%
# View a single job description
print(df.loc[0].job_description)
# Out:
# Data Analyst I
# ==============
#
# [Mullen Coughlin LLC](https://www.indeed.com/cmp/Mullen-Coughlin-LLC?campaignid=mobvjcmp&from=mobviewjob&tk=1htap02b1k7dj800&fromjk=4e8e460151894b34)3.2 out of 5RemoteFull-time[Mullen Coughlin LLC
# -------------------
#
# 5 reviewsRead what people are saying about working here.](https://www.indeed.com/cmp/Mullen-Coughlin-LLC/reviews?campaignid=mobvjcmp&cmpratingc=mobviewjob&from=mobviewjob&tk=1htap02b1k7dj800&fromjk=4e8e460151894b34&jt=Data+Analyst+I)Profile insights
# ----------------
#
# Find out how your skills align with the job description### Skills
#
# Do you have experience in **SQL**?YesNo### Education
#
# Do you have a **Bachelor's degree**?YesNo&nbsp;Job details
# -----------
#
# Here’s how the job details align with your [profile](https://profile.indeed.com/).### Job type
#
# * Full-time
# &nbsp;Location
# --------
#
# Remote&nbsp;BenefitsPulled from the full job description
# --------------------------------------------
#
# * 401(k)
# * Work from home
# &nbsp;Full job description
# --------------------
#
#
#
#  Data Analyst I
#
#
#
#  Mullen Coughlin is a highly successful, fast growing niche law firm focused exclusively on counseling organizations in the context of data privacy, including incident response, regulatory investigation, single-plaintiff and class action litigation compliance. Committed to rapid incident response to incoming client calls, we thrive in a high energy, close-knit, and upbeat office culture. The Firm pays very competitively in the market and offers a full benefit package, including accrued time off and a generous 401(k) program. At its new location, 426 West Lancaster Avenue, Devon, PA, Mullen Coughlin’s home office is over fifty-six thousand square feet, boasting the latest in technology and security, accommodating the projected continued growth of the firm, and providing all Mullen Coughlin employees access to amenities and resources to further their professional careers, as well as their health and well-being.
#
#
#
#  We are looking for a new Data Analyst I to join our team! The ideal candidate will demonstrate creative, technical, and interpersonal skills, and the ability to work closely with other members of the team. This is a full-time, non-exempt position with the option to work remotely.
#
#
#
# **Sample of Essential Responsibilities**
#
# * Efficiently interpret and organize sensitive data sets to support legal matters related to data privacy cases.
# * Develop applicable data analytics and processing tools/systems to enable expedited processing of data sets.
# * Use different coding methods to clean, manipulate, and transform data received from various sources.
# * Perform initial analysis to assess quality of data.
# * Identify, analyze, and interpret trends or patterns in complex data sets.
# * Work with Data Engineer(s), CIO, and designated Attorneys to prioritize business and information needs.
# * Work effectively with teammates in a fast-paced environment meeting hard deadlines and potentially short turnaround times.
# * Provide timely status reports and updates to management or attorneys about various duties and assignments.
# * Communicate data analytic insights to various internal and external clients when applicable.
# * Design and create scalable solutions for data management and other process improvements.
# * Support the firm with other database/analytics projects as directed.
#
#
#
#
# **Desired Skills, Qualifications, and Experience**
#
# * Must have highest integrity and the ability to treat confidential information appropriately.
# * 1+ years’ experience working with data management or as a data analyst.
# * BS in Computer Science or related field, *a plus but not required*.
# * Advanced Excel skills and experience writing excel functions to manipulate/enrich data (i.e. if-then statements, vlookups, text-join, left, mid, right, etc.)
# * 1+ year programming experience in Python, *preferred*.
# * Experience with SQL, MySQL, and/or PostgreSQL.
# * Experience using source control, *a plus* (Git).
# * Data analytics, big data, and/or other IT certifications, *a plus*.
# * A resourceful problem-solver who seeks out effective and efficient solutions.
# * Excellent interpersonal and verbal/written communications skills; adaptability; and situational sensitivity.
# * Candidate should be comfortable balancing multiple assignments/cases.
# * Demonstrated process improvement experience, resourcefulness, and the interest to develop scalable data management solutions.
# * Google Cloud Certified Professional Data Engineer, *preferred*.
# * Successful candidate will be required to obtain Google Cloud Certified Professional Data Engineer certification within 6 months of hire.
#
#
#
#
# **To Apply**
#
#
#  Please complete an online application and include your cover letter, resume and target salary range.
#
#
#
# ***Mullen Coughlin is an Equal Opportunity Employee and believes in strength in diversity.***
#
#
# ***Mullen Coughlin is not accepting resumes from search firms for this position.***
#
#
# ***Relocation assistance is not provided for this position.***
#  ﻿
#
# ***Applicant must be authorized to work in the United States of America.***
#
# If you require alternative methods of application or screening, you must approach the employer directly to request this as Indeed is not responsible for the employer's application process.Apply nowsave-icon&nbsp;Report job

# %%
# Print the job description with the links removed, if you're trying to save on tokens (for ai stuff)
from indeed_scraper import IndeedScraper
scraper = IndeedScraper()
print(scraper.remove_links_from_markdown(df.loc[0].job_description))
# Out:
# Indeed Scraper Initialized
# Data Analyst I==============[Mullen Coughlin LLC](<url removed>)3.2 out of 5RemoteFull-time[Mullen Coughlin LLC-------------------5 reviewsRead what people are saying about working here.](<url removed>)Profile insights----------------Find out how your skills align with the job description### SkillsDo you have experience in **SQL**?YesNo### EducationDo you have a **Bachelor's degree**?YesNo&nbsp;Job details-----------Here’s how the job details align with your [profile](<url removed>).### Job type* Full-time&nbsp;Location--------Remote&nbsp;BenefitsPulled from the full job description--------------------------------------------* 401(k)* Work from home&nbsp;Full job description-------------------- Data Analyst I  Mullen Coughlin is a highly successful, fast growing niche law firm focused exclusively on counseling organizations in the context of data privacy, including incident response, regulatory investigation, single-plaintiff and class action litigation compliance. Committed to rapid incident response to incoming client calls, we thrive in a high energy, close-knit, and upbeat office culture. The Firm pays very competitively in the market and offers a full benefit package, including accrued time off and a generous 401(k) program. At its new location, 426 West Lancaster Avenue, Devon, PA, Mullen Coughlin’s home office is over fifty-six thousand square feet, boasting the latest in technology and security, accommodating the projected continued growth of the firm, and providing all Mullen Coughlin employees access to amenities and resources to further their professional careers, as well as their health and well-being.  We are looking for a new Data Analyst I to join our team! The ideal candidate will demonstrate creative, technical, and interpersonal skills, and the ability to work closely with other members of the team. This is a full-time, non-exempt position with the option to work remotely. **Sample of Essential Responsibilities*** Efficiently interpret and organize sensitive data sets to support legal matters related to data privacy cases.* Develop applicable data analytics and processing tools/systems to enable expedited processing of data sets.* Use different coding methods to clean, manipulate, and transform data received from various sources.* Perform initial analysis to assess quality of data.* Identify, analyze, and interpret trends or patterns in complex data sets.* Work with Data Engineer(s), CIO, and designated Attorneys to prioritize business and information needs.* Work effectively with teammates in a fast-paced environment meeting hard deadlines and potentially short turnaround times.* Provide timely status reports and updates to management or attorneys about various duties and assignments.* Communicate data analytic insights to various internal and external clients when applicable.* Design and create scalable solutions for data management and other process improvements.* Support the firm with other database/analytics projects as directed.**Desired Skills, Qualifications, and Experience*** Must have highest integrity and the ability to treat confidential information appropriately.* 1+ years’ experience working with data management or as a data analyst.* BS in Computer Science or related field, *a plus but not required*.* Advanced Excel skills and experience writing excel functions to manipulate/enrich data (i.e. if-then statements, vlookups, text-join, left, mid, right, etc.)* 1+ year programming experience in Python, *preferred*.* Experience with SQL, MySQL, and/or PostgreSQL.* Experience using source control, *a plus* (Git).* Data analytics, big data, and/or other IT certifications, *a plus*.* A resourceful problem-solver who seeks out effective and efficient solutions.* Excellent interpersonal and verbal/written communications skills; adaptability; and situational sensitivity.* Candidate should be comfortable balancing multiple assignments/cases.* Demonstrated process improvement experience, resourcefulness, an ...
